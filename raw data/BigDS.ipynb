# %%
import pandas as pd
import requests
import json
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
# Out:
# C:\Users\LENOVO\AppData\Roaming\Python\Python37\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (2.0.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
api_key = "AIzaSyBN0w8hAwguRI2KB7mOoSv3GqWAoDXySQc"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="Education",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel =20
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('BigDS.csv',index=False)
# Out:
# 40
# 800

# %%
api_key = "AIzaSyAfKjrh1o4Q7e71p9VmQLnrBu9pxoERAbc"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="Travel & Events",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 23
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('BigDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 439

# %%
api_key = "AIzaSyCk6Sm8zhQ36mYKYevzmRtsbDacBfnZI1o"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="music",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 20
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('BigDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 800

# %%
api_key = "AIzaSyBWRJ9YXKhkh9JzWcBqSelFL3lCLm8-T6M"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="People & Blogs",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 25
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('BigDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 408

# %%
api_key = "AIzaSyAHrI36hneMV7N2829Pug8O6yMArMEMMuI"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="Sports",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 25
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('BigDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 944

# %%
api_key = "AIzaSyDxBNIFficFsDnTKamwxze9CeTNkrFGPmE"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="Entertainment",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 25
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('BigDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 1000

# %%
api_key = "AIzaSyBTW52KHj3WpgR2zA8Vrrnc4GodE1gazno"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="Film & Animation",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 25
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('BigDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 748

# %%
api_key = "AIzaSyBNsKqQ5mhORyJmRRYnsp5Ut6Uc3bKi78A"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="Beauty & fashion",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 25
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('BigDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 993

# %%
api_key = "AIzaSyD9nGu0UY--zs7e8tSKQJFdE-pVl9z_-i0"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="Gaming",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 27
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('BigDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 1080

# %%
api_key = "AIzaSyAkjZHm56r9JZnarNz6m63ZC35GKy2KXP4"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="Cooking & food",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 27
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('BigDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 1063

# %%
api_key = "AIzaSyDJWGgh1fuHMCSOSB4lEA6tseSpNhnNiqQ"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="Health & fitness",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 27
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('BigDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 880

# %%
api_key = "AIzaSyAIFVaDoyZygGA80DK5YXgAJU1ZWHoYvBI"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="Art & Design",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 20
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('BigDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 578

# %%
api_key = "AIzaSyDS242aklFTxA4Y5mzllUMD0K2-CTl2cnY"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="Kids & Family",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 7
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('BigDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 253

# %%
import pandas as pd
data = pd.read_csv('BigDS.csv')
print(len(data))
# Out:
# 9986

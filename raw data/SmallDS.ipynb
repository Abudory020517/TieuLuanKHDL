# %%
import pandas as pd
import requests
import json
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %%
api_key = "AIzaSyD5ukx7IOD8vEJApkuyDHvEEHfzghTCGo0"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="Education",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 5
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('SmallDS.csv',index=False)
# Out:
# 40
# 200

# %%
api_key = "AIzaSyA3u-PtDw1ajHK-qEf988_MoUO0LZtPdnU"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="Travel & Events",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 5
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('SmallDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 169

# %%
api_key = "AIzaSyAftUjw0ZgEFUF0Sn7afWSRpexh2jQZQq8"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="music",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 4
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('SmallDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 160

# %%
api_key = "AIzaSyAQbcajIIqj3XvY-yHg1lK2t2GK4jQTjI4"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="People & Blogs",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 4
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('SmallDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 133

# %%
api_key = "AIzaSyCQLG0WtCG1aELMwSnP75nghB7Xte5Zgoo"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="Sports",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 3
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('SmallDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 119

# %%
api_key = "AIzaSyArtz9MiWLyiyUpCT9zLb9UJMAFie2bsG0"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="Entertainment",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 3
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('SmallDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 120

# %%
api_key = "AIzaSyApdMZDIHjQ1HZWjhrDFKWl_Iza4s1yYkQ"
youtube = build('youtube', 'v3', developerKey=api_key)

search_response = youtube.search().list(
    q="Film & Animation",
    type='channel',
    part='id',
    maxResults=40
).execute()

# Lấy danh sách các ID kênh từ kết quả tìm kiếm
channel_IDs = [item['id']['channelId'] for item in search_response['items']] 
print(len(channel_IDs))

max_videos_per_channel = 4
video_ids = []

for channel_ID in channel_IDs:
    next_page_token = None
    videos_per_channel = 0
    while True:
        max_results = min(max_videos_per_channel - videos_per_channel, 50)
        url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults={max_results}"
        if next_page_token:
            url += f"&pageToken={next_page_token}"
        data = json.loads(requests.get(url).text)
        for item in data['items']:
            if 'videoId' in item['id']:
                video_id = str(item['id']['videoId'])
                video_ids.append(video_id)
                videos_per_channel += 1
                if videos_per_channel >= max_videos_per_channel:
                    break
        if videos_per_channel >= max_videos_per_channel:
            break
        if 'nextPageToken' in data:
            next_page_token = data['nextPageToken']
        else:
            break

print(len(video_ids))

data_df = pd.DataFrame(columns=["video_id","channel_id","channel_name","published_date","video_title","video_description","dislikes","likes","views","comment_count","favorite_count","category","subscribers","duration"])


for i, video_id in enumerate(video_ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?&part=statistics,snippet,contentDetails&key={api_key}&id={video_id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']
    channel_title = data['items'][0]['snippet']['channelTitle']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    description = data['items'][0]['snippet']['description']
    dislikes = data['items'][0]['statistics'].get('dislikeCount', 0)
    likes = data['items'][0]['statistics'].get('likeCount',0)
    views = data['items'][0]['statistics'].get('viewCount',0)
    comment_count = data['items'][0]['statistics'].get('commentCount',0)
    favorite_count = data['items'][0]['statistics'].get('favoriteCount',0)
    category = data['items'][0]['snippet']['categoryId']
    duration = data['items'][0]['contentDetails']['duration']
    
    # Truy vấn thông tin kênh
    channel_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}"
    channel_data = json.loads(requests.get(channel_url).text)
    subscribers = channel_data['items'][0]['statistics'].get('subscriberCount',0)

    row =[video_id,channel_id,channel_title,published_date,video_title,description,dislikes,likes,views,comment_count,favorite_count,category,subscribers,duration]
    data_df.loc[i]=row

data_df.to_csv('SmallDS.csv', mode='a', header=False, index=False)
# Out:
# 40
# 156

# %%
import pandas as pd
data = pd.read_csv('SmallDS.csv')
print(len(data))
# Out:
# 1057
